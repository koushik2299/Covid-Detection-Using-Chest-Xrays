# %% [markdown]
# ### **Use this Notebook on Google Colab Free GPU**
# Go to Google Drive, upload this notebook and dataset folders. Rigth click notebook, choose **Open with -> Google Colab**
# <br>
# To activate GPU in Colab, go to **Runtime -> Change Runtime Type**. Under **Hardware accelerator** choose **GPU**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Connect to Google Drive to access Dataset

# %% [markdown]
# ### Import all dependencies

# %%
from __future__ import print_function, division
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
import pandas as pd

# %% [markdown]
# ### Define Few Parameters

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224] # feel free to change depending on dataset

# training config:
epochs = 500
batch_size = 32

#define paths
covid_path = '/content/drive/MyDrive/CovidDataset/COVID POSITIVE'
noncovid_path = '/content/drive/MyDrive/CovidDataset/COVID NEGATIVE'

# Use glob to grab images from path .jpg or jpeg
covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %% [markdown]
# ### Fetch Images and Class Labels from Files (This might take a while)

# %%
# Preparing Labels
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

import cv2 

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  covid_images.append(image)
  covid_labels.append('Chest_COVID')
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('Chest_NonCOVID')

# %% [markdown]
# ### Visualize First 40 Images from Data set

# %%
# look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 Chest X-ray')
plot_images(noncovid_images, 'Negative COVID-19 Chest X-ray')

# %% [markdown]
# ### **Normalization**
# #### Model takes images in the form of array of pixels. Hence convert into array and *normalize*

# %%
# Convert to array and Normalize to interval of [0,1]
covid_images = np.array(covid_images) / 255
noncovid_images = np.array(noncovid_images) / 255

# %% [markdown]
# ### **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# split into training and testing
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)


X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Visualize a few images from Training and Test sets

# %%
plot_images(covid_x_train, 'X_train')
plot_images(covid_x_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-00e952fc29dd> in <module>()
#       1 plot_images(covid_x_train, 'X_train')
# ----> 2 plot_images(covid_x_test, 'X_test')
#       3 # y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test
#
# <ipython-input-5-2bbfdf3afaa6> in plot_images(images, title)
#       7
#       8     for i, axi in enumerate(ax.flat):
# ----> 9         axi.imshow(images[i])
#      10         axi.set_axis_off()
#      11
#
# IndexError: index 29 is out of bounds for axis 0 with size 29

# %% [markdown]
# ### **Building and Visualizing model**

# %%
vggModel = VGG19(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = vggModel.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=vggModel.input, outputs=outputs)

for layer in vggModel.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ### **Image Augmentation**
# To train on images at different positions, angles, flips, etc

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %% [markdown]
# ### **Training the model**

# %%
history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 23s 1s/step - loss: 2.1951 - accuracy: 0.4779 - val_loss: 0.9960 - val_accuracy: 0.5000
# Epoch 2/100
# 7/7 [==============================] - 3s 424ms/step - loss: 0.8054 - accuracy: 0.6681 - val_loss: 0.0575 - val_accuracy: 1.0000
# Epoch 3/100
# 7/7 [==============================] - 3s 412ms/step - loss: 0.3180 - accuracy: 0.8540 - val_loss: 0.0420 - val_accuracy: 0.9828
# Epoch 4/100
# 7/7 [==============================] - 3s 414ms/step - loss: 0.2539 - accuracy: 0.8938 - val_loss: 0.1013 - val_accuracy: 0.9483
# Epoch 5/100
# 7/7 [==============================] - 3s 466ms/step - loss: 0.1352 - accuracy: 0.9602 - val_loss: 0.0377 - val_accuracy: 0.9828
# Epoch 6/100
# 7/7 [==============================] - 3s 399ms/step - loss: 0.1495 - accuracy: 0.9381 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 7/100
# 7/7 [==============================] - 3s 423ms/step - loss: 0.0836 - accuracy: 0.9558 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 8/100
# 7/7 [==============================] - 3s 413ms/step - loss: 0.0863 - accuracy: 0.9735 - val_loss: 0.0232 - val_accuracy: 0.9828
# Epoch 9/100
# 7/7 [==============================] - 3s 415ms/step - loss: 0.1330 - accuracy: 0.9513 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 10/100
# 7/7 [==============================] - 3s 413ms/step - loss: 0.0706 - accuracy: 0.9867 - val_loss: 0.0258 - val_accuracy: 0.9828
# Epoch 11/100
# 7/7 [==============================] - 3s 466ms/step - loss: 0.0649 - accuracy: 0.9690 - val_loss: 0.0285 - val_accuracy: 0.9828
# Epoch 12/100
# 7/7 [==============================] - 3s 420ms/step - loss: 0.1229 - accuracy: 0.9513 - val_loss: 0.0506 - val_accuracy: 0.9828
# Epoch 13/100
# 7/7 [==============================] - 3s 420ms/step - loss: 0.0866 - accuracy: 0.9690 - val_loss: 0.0287 - val_accuracy: 0.9828
# Epoch 14/100
# 7/7 [==============================] - 3s 419ms/step - loss: 0.0640 - accuracy: 0.9779 - val_loss: 0.1072 - val_accuracy: 0.9655
# Epoch 15/100
# 7/7 [==============================] - 3s 418ms/step - loss: 0.0951 - accuracy: 0.9823 - val_loss: 0.0599 - val_accuracy: 0.9828
# Epoch 16/100
# 7/7 [==============================] - 3s 419ms/step - loss: 0.0469 - accuracy: 0.9823 - val_loss: 0.0483 - val_accuracy: 0.9828
# Epoch 17/100
# 7/7 [==============================] - 3s 419ms/step - loss: 0.0795 - accuracy: 0.9602 - val_loss: 0.0567 - val_accuracy: 0.9828
# Epoch 18/100
# 7/7 [==============================] - 3s 413ms/step - loss: 0.0992 - accuracy: 0.9690 - val_loss: 0.1168 - val_accuracy: 0.9310
# Epoch 19/100
# 7/7 [==============================] - 3s 422ms/step - loss: 0.1039 - accuracy: 0.9513 - val_loss: 0.1052 - val_accuracy: 0.9655
# Epoch 20/100
# 7/7 [==============================] - 3s 417ms/step - loss: 0.0411 - accuracy: 0.9912 - val_loss: 0.0990 - val_accuracy: 0.9655
# Epoch 21/100
# 7/7 [==============================] - 3s 477ms/step - loss: 0.0354 - accuracy: 0.9823 - val_loss: 0.0708 - val_accuracy: 0.9828
# Epoch 22/100
# 7/7 [==============================] - 3s 420ms/step - loss: 0.0367 - accuracy: 0.9823 - val_loss: 0.0685 - val_accuracy: 0.9828
# Epoch 23/100
# 7/7 [==============================] - 3s 409ms/step - loss: 0.0431 - accuracy: 0.9867 - val_loss: 0.0729 - val_accuracy: 0.9828
# Epoch 24/100
# 7/7 [==============================] - 3s 411ms/step - loss: 0.0582 - accuracy: 0.9867 - val_loss: 0.0971 - val_accuracy: 0.9655
# Epoch 25/100
# 7/7 [==============================] - 3s 424ms/step - loss: 0.0368 - accuracy: 0.9823 - val_loss: 0.0544 - val_accuracy: 0.9828
# Epoch 26/100
# 7/7 [==============================] - 3s 424ms/step - loss: 0.0305 - accuracy: 0.9912 - val_loss: 0.0872 - val_accuracy: 0.9655
# Epoch 27/100
# 7/7 [==============================] - 3s 425ms/step - loss: 0.0464 - accuracy: 0.9823 - val_loss: 0.0534 - val_accuracy: 0.9828
# Epoch 28/100
# 7/7 [==============================] - 3s 422ms/step - loss: 0.0314 - accuracy: 0.9956 - val_loss: 0.0831 - val_accuracy: 0.9655
# Epoch 29/100
# 7/7 [==============================] - 3s 410ms/step - loss: 0.0268 - accuracy: 0.9956 - val_loss: 0.0715 - val_accuracy: 0.9828
# Epoch 30/100
# 7/7 [==============================] - 3s 421ms/step - loss: 0.0534 - accuracy: 0.9779 - val_loss: 0.0720 - val_accuracy: 0.9828
# Epoch 31/100
# 7/7 [==============================] - 3s 410ms/step - loss: 0.0488 - accuracy: 0.9867 - val_loss: 0.0457 - val_accuracy: 0.9828
# Epoch 32/100
# 7/7 [==============================] - 3s 481ms/step - loss: 0.0347 - accuracy: 0.9912 - val_loss: 0.0466 - val_accuracy: 0.9828
# Epoch 33/100
# 7/7 [==============================] - 3s 414ms/step - loss: 0.0671 - accuracy: 0.9779 - val_loss: 0.0465 - val_accuracy: 0.9828
# Epoch 34/100
# 7/7 [==============================] - 3s 423ms/step - loss: 0.1702 - accuracy: 0.9292 - val_loss: 0.1688 - val_accuracy: 0.9655
# Epoch 35/100
# 7/7 [==============================] - 3s 422ms/step - loss: 0.1853 - accuracy: 0.9204 - val_loss: 0.0686 - val_accuracy: 0.9828
# Epoch 36/100
# 7/7 [==============================] - 3s 415ms/step - loss: 0.1031 - accuracy: 0.9558 - val_loss: 0.0591 - val_accuracy: 0.9828
# Epoch 37/100
# 7/7 [==============================] - 3s 416ms/step - loss: 0.0440 - accuracy: 0.9735 - val_loss: 0.0696 - val_accuracy: 0.9828
# Epoch 38/100
# 7/7 [==============================] - 3s 406ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9828
# Epoch 39/100
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0315 - accuracy: 0.9912 - val_loss: 0.0755 - val_accuracy: 0.9828
# Epoch 40/100
# 7/7 [==============================] - 3s 417ms/step - loss: 0.0223 - accuracy: 0.9912 - val_loss: 0.0668 - val_accuracy: 0.9828
# Epoch 41/100
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0168 - accuracy: 0.9956 - val_loss: 0.0550 - val_accuracy: 0.9828
# Epoch 42/100
# 7/7 [==============================] - 3s 478ms/step - loss: 0.0431 - accuracy: 0.9823 - val_loss: 0.0829 - val_accuracy: 0.9828
# Epoch 43/100
# 7/7 [==============================] - 3s 424ms/step - loss: 0.0763 - accuracy: 0.9602 - val_loss: 0.1830 - val_accuracy: 0.9310
# Epoch 44/100
# 7/7 [==============================] - 3s 424ms/step - loss: 0.0620 - accuracy: 0.9735 - val_loss: 0.1047 - val_accuracy: 0.9655
# Epoch 45/100
# 7/7 [==============================] - 3s 434ms/step - loss: 0.0852 - accuracy: 0.9646 - val_loss: 0.0532 - val_accuracy: 0.9828
# Epoch 46/100
# 7/7 [==============================] - 3s 432ms/step - loss: 0.0396 - accuracy: 0.9779 - val_loss: 0.0535 - val_accuracy: 0.9828
# Epoch 47/100
# 7/7 [==============================] - 3s 420ms/step - loss: 0.0821 - accuracy: 0.9690 - val_loss: 0.1223 - val_accuracy: 0.9655
# Epoch 48/100
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0937 - accuracy: 0.9690 - val_loss: 0.0508 - val_accuracy: 0.9828
# Epoch 49/100
# 7/7 [==============================] - 3s 424ms/step - loss: 0.0347 - accuracy: 0.9912 - val_loss: 0.0460 - val_accuracy: 0.9828
# Epoch 50/100
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.0535 - val_accuracy: 0.9828
# Epoch 51/100
# 7/7 [==============================] - 3s 426ms/step - loss: 0.0164 - accuracy: 0.9956 - val_loss: 0.0663 - val_accuracy: 0.9828
# Epoch 52/100
# 7/7 [==============================] - 3s 429ms/step - loss: 0.0298 - accuracy: 0.9912 - val_loss: 0.0443 - val_accuracy: 0.9828
# Epoch 53/100
# 7/7 [==============================] - 3s 486ms/step - loss: 0.0236 - accuracy: 0.9956 - val_loss: 0.0398 - val_accuracy: 0.9828
# Epoch 54/100
# 7/7 [==============================] - 3s 433ms/step - loss: 0.0351 - accuracy: 0.9867 - val_loss: 0.0764 - val_accuracy: 0.9828
# Epoch 55/100
# 7/7 [==============================] - 3s 418ms/step - loss: 0.0379 - accuracy: 0.9779 - val_loss: 0.0418 - val_accuracy: 0.9828
# Epoch 56/100
# 7/7 [==============================] - 3s 494ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0508 - val_accuracy: 0.9828
# Epoch 57/100
# 7/7 [==============================] - 3s 484ms/step - loss: 0.0205 - accuracy: 0.9867 - val_loss: 0.0512 - val_accuracy: 0.9828
# Epoch 58/100
# 7/7 [==============================] - 3s 433ms/step - loss: 0.0393 - accuracy: 0.9912 - val_loss: 0.0366 - val_accuracy: 0.9828
# Epoch 59/100
# 7/7 [==============================] - 3s 433ms/step - loss: 0.0234 - accuracy: 0.9912 - val_loss: 0.0604 - val_accuracy: 0.9828
# Epoch 60/100
# 7/7 [==============================] - 3s 430ms/step - loss: 0.0167 - accuracy: 0.9956 - val_loss: 0.0519 - val_accuracy: 0.9828
# Epoch 61/100
# 7/7 [==============================] - 3s 419ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9828
# Epoch 62/100
# 7/7 [==============================] - 3s 432ms/step - loss: 0.0232 - accuracy: 0.9867 - val_loss: 0.0385 - val_accuracy: 0.9828
# Epoch 63/100
# 7/7 [==============================] - 3s 421ms/step - loss: 0.0272 - accuracy: 0.9867 - val_loss: 0.0704 - val_accuracy: 0.9828
# Epoch 64/100
# 7/7 [==============================] - 3s 430ms/step - loss: 0.0168 - accuracy: 0.9912 - val_loss: 0.0532 - val_accuracy: 0.9828
# Epoch 65/100
# 7/7 [==============================] - 3s 430ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.0441 - val_accuracy: 0.9828
# Epoch 66/100
# 7/7 [==============================] - 3s 425ms/step - loss: 0.0160 - accuracy: 0.9956 - val_loss: 0.0423 - val_accuracy: 0.9828
# Epoch 67/100
# 7/7 [==============================] - 3s 429ms/step - loss: 0.0160 - accuracy: 0.9956 - val_loss: 0.0428 - val_accuracy: 0.9828
# Epoch 68/100
# 7/7 [==============================] - 3s 423ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 0.0481 - val_accuracy: 0.9828
# Epoch 69/100
# 7/7 [==============================] - 3s 432ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9828
# Epoch 70/100
# 7/7 [==============================] - 3s 429ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9828
# Epoch 71/100
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0178 - accuracy: 0.9956 - val_loss: 0.0571 - val_accuracy: 0.9828
# Epoch 72/100
# 7/7 [==============================] - 3s 416ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9828
# Epoch 73/100
# 7/7 [==============================] - 3s 426ms/step - loss: 0.0186 - accuracy: 0.9956 - val_loss: 0.0829 - val_accuracy: 0.9828
# Epoch 74/100
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0517 - val_accuracy: 0.9828
# Epoch 75/100
# 7/7 [==============================] - 3s 433ms/step - loss: 0.0071 - accuracy: 0.9956 - val_loss: 0.0663 - val_accuracy: 0.9828
# Epoch 76/100
# 7/7 [==============================] - 3s 431ms/step - loss: 0.0232 - accuracy: 0.9956 - val_loss: 0.0907 - val_accuracy: 0.9828
# Epoch 77/100
# 7/7 [==============================] - 3s 420ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9828
# Epoch 78/100
# 7/7 [==============================] - 3s 429ms/step - loss: 0.0264 - accuracy: 0.9912 - val_loss: 0.0859 - val_accuracy: 0.9828
# Epoch 79/100
# 7/7 [==============================] - 3s 432ms/step - loss: 0.0113 - accuracy: 0.9956 - val_loss: 0.0901 - val_accuracy: 0.9828
# Epoch 80/100
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0186 - accuracy: 0.9912 - val_loss: 0.0549 - val_accuracy: 0.9828
# Epoch 81/100
# 7/7 [==============================] - 3s 414ms/step - loss: 0.0171 - accuracy: 0.9912 - val_loss: 0.0589 - val_accuracy: 0.9828
# Epoch 82/100
# 7/7 [==============================] - 3s 431ms/step - loss: 0.0171 - accuracy: 0.9956 - val_loss: 0.0529 - val_accuracy: 0.9828
# Epoch 83/100
# 7/7 [==============================] - 3s 492ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.0589 - val_accuracy: 0.9828
# Epoch 84/100
# 7/7 [==============================] - 3s 434ms/step - loss: 0.0289 - accuracy: 0.9823 - val_loss: 0.0640 - val_accuracy: 0.9828
# Epoch 85/100
# 7/7 [==============================] - 3s 433ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9828
# Epoch 86/100
# 7/7 [==============================] - 3s 434ms/step - loss: 0.0164 - accuracy: 0.9956 - val_loss: 0.0755 - val_accuracy: 0.9828
# Epoch 87/100
# 7/7 [==============================] - 3s 436ms/step - loss: 0.0118 - accuracy: 0.9956 - val_loss: 0.0615 - val_accuracy: 0.9828
# Epoch 88/100
# 7/7 [==============================] - 3s 430ms/step - loss: 0.0125 - accuracy: 0.9956 - val_loss: 0.0572 - val_accuracy: 0.9828
# Epoch 89/100
# 7/7 [==============================] - 3s 436ms/step - loss: 0.0102 - accuracy: 0.9956 - val_loss: 0.0540 - val_accuracy: 0.9828
# Epoch 90/100
# 7/7 [==============================] - 3s 429ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9828
# Epoch 91/100
# 7/7 [==============================] - 3s 488ms/step - loss: 0.0089 - accuracy: 0.9956 - val_loss: 0.0566 - val_accuracy: 0.9828
# Epoch 92/100
# 7/7 [==============================] - 3s 484ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.0670 - val_accuracy: 0.9828
# Epoch 93/100
# 7/7 [==============================] - 3s 430ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9828
# Epoch 94/100
# 7/7 [==============================] - 3s 427ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.0534 - val_accuracy: 0.9655
# Epoch 95/100
# 7/7 [==============================] - 3s 432ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.0875 - val_accuracy: 0.9828
# Epoch 96/100
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0226 - accuracy: 0.9912 - val_loss: 0.0658 - val_accuracy: 0.9655
# Epoch 97/100
# 7/7 [==============================] - 3s 429ms/step - loss: 0.0162 - accuracy: 0.9956 - val_loss: 0.0865 - val_accuracy: 0.9828
# Epoch 98/100
# 7/7 [==============================] - 3s 437ms/step - loss: 0.0406 - accuracy: 0.9823 - val_loss: 0.0847 - val_accuracy: 0.9828
# Epoch 99/100
# 7/7 [==============================] - 3s 487ms/step - loss: 0.0278 - accuracy: 0.9912 - val_loss: 0.0506 - val_accuracy: 0.9655
# Epoch 100/100
# 7/7 [==============================] - 3s 490ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9655

# %%
model.save('vgg_chest.h5')

# %%
model.save_weights('vggweights_chest.hdf5')

# %%
model = load_model('vgg_chest.h5')

# %% [markdown]
# ### **Making Predicions**

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %% [markdown]
# ### Visulaizing First 10 predictions

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% COVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% NonCOVID')
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %% [markdown]
# ### Plot ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %% [markdown]
# ### Plot Confusion Matrix

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %% [markdown]
# ### **Classification Report**

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        29
#            1       1.00      0.93      0.96        29
#
#     accuracy                           0.97        58
#    macro avg       0.97      0.97      0.97        58
# weighted avg       0.97      0.97      0.97        58

# %% [markdown]
# ### **Accuracy and Loss Plots**

# %%
plt.figure(figsize=(10,5))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy',fontsize=20)
plt.ylabel('Accuracy',fontsize=20)
plt.xlabel('Epoch',fontsize=20)

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_chest_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss',fontsize=20)
plt.ylabel('Loss',fontsize=20)
plt.xlabel('Epoch',fontsize=20)

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_chest_loss.png')
plt.show()

# %%
plt.figure(figsize=(5,7))
plt.boxplot(history.history['accuracy'])
plt.title("VGG-16 Accuracy Box Plot",fontsize=20)
plt.show()
